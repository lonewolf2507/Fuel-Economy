# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_08 = pd.read_csv("D:/data analyst projects/fuel economy/all_alpha_08.csv")
df_18 = pd.read_csv("D:/data analyst projects/fuel economy/all_alpha_18.csv")

# %%
df_08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df_18
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %%
# checking duplicates
df_08.duplicated().sum()
# Out:
# 25

# %%
df_18.duplicated().sum()
# Out:
# 0

# %%
# dropping unnecessary columns

df_08 = df_08.drop(['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'] , axis = 'columns')
df_08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# ...           ...    ...      ...      ...   ...       ...        ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
df_18 = df_18.drop(['Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'] , axis = 'columns')
df_18
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region     Veh Class  Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
# renaming the column in 2008 database so that it matches that of our 2018 databse
df_08.rename(columns= {'Sales Area' : 'Cert Region'} , inplace  = True)

# %%
df_08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Cert Region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
# changing the spaces in column name to _ and converting uppercae to lowercase so it is easy to work around

df_08.columns = [column.replace(' ' ,'_').lower() for column in df_08.columns]
df_08
# Out:
#             model  displ      cyl    trans drive      fuel cert_region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_18.columns = [column.replace(' ' ,'_').lower() for column in df_18.columns]
df_18
# Out:
#             model  displ  cyl       trans drive                  fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      cert_region     veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
# creating a query where only ca certified data is chosen
df_08 = df_08.query('cert_region == "CA"')
df_08
# Out:
#             model  displ      cyl    trans drive      fuel cert_region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 6        ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# 7        ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2394    VOLVO V70    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          CA
# 2396  VOLVO XC 70    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2398  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          CA
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
#
#           veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_18 = df_18.query('cert_region == "CA"')
df_18
# Out:
#             model  displ  cyl       trans drive                  fuel  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      cert_region     veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_08 = df_08.drop('cert_region' , axis = 'columns')

# %%
df_18 = df_18.drop('cert_region' , axis = 'columns')

# %%
# drop rows with empty rows
df_08 = df_08.dropna()
df_08.shape
# Out:
# (1009, 13)

# %%
df_18 = df_18.dropna()
df_18.shape
# Out:
# (797, 13)

# %%
# drop duplicate rows

df_08.drop_duplicates()
df_08.shape
# Out:
# (1009, 13)

# %%
df_18.drop_duplicates()
df_18.shape
# Out:
# (797, 13)

# %%
#*fixing data types*

# checking data types
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1009 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 1009 non-null   object
#  1   displ                 1009 non-null   float64
#  2   cyl                   1009 non-null   object
#  3   trans                 1009 non-null   object
#  4   drive                 1009 non-null   object
#  5   fuel                  1009 non-null   object
#  6   veh_class             1009 non-null   object
#  7   air_pollution_score   1009 non-null   object
#  8   city_mpg              1009 non-null   object
#  9   hwy_mpg               1009 non-null   object
#  10  cmb_mpg               1009 non-null   object
#  11  greenhouse_gas_score  1009 non-null   object
#  12  smartway              1009 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 110.4+ KB

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 797 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 797 non-null    object
#  1   displ                 797 non-null    float64
#  2   cyl                   797 non-null    float64
#  3   trans                 797 non-null    object
#  4   drive                 797 non-null    object
#  5   fuel                  797 non-null    object
#  6   veh_class             797 non-null    object
#  7   air_pollution_score   797 non-null    int64
#  8   city_mpg              797 non-null    object
#  9   hwy_mpg               797 non-null    object
#  10  cmb_mpg               797 non-null    object
#  11  greenhouse_gas_score  797 non-null    int64
#  12  smartway              797 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 87.2+ KB

# %%
# extract int from string i.e. 6 from 6 cyl

df_08['cyl'] = df_08['cyl'].str.extract('(\d+)')

# %% [markdown]
# The SettingWithCopyWarning was created to flag potentially confusing "chained" assignments, such as the following, which does not always work as expected, particularly when the first selection returns a copy.
#
#
# FALSE poisitive warning in our case

# %%
df_08['cyl'].astype('int64')
# Out:
# 0       6
# 2       4
# 4       6
# 6       6
# 7       6
#        ..
# 2394    6
# 2396    6
# 2398    6
# 2399    6
# 2400    8
# Name: cyl, Length: 1009, dtype: int64

# %%
df_08['cyl'].dtypes
# Out:
# dtype('O')

# %%
df_08['cyl'] = df_08['cyl'].astype('int64')
df_08['cyl'].dtypes
# Out:
# dtype('int64')

# %%
df_18['cyl'].astype('int64')
# Out:
# 1       6
# 3       6
# 4       4
# 6       6
# 8       6
#        ..
# 1601    4
# 1603    4
# 1605    4
# 1607    4
# 1609    4
# Name: cyl, Length: 797, dtype: int64

# %%
df_08 = df_08.reset_index().drop(['index'] , axis = 1)
df_08
# Out:
#             model  displ  cyl    trans drive      fuel      veh_class  \
# 0       ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline            SUV
# 1       ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline            SUV
# 2        ACURA RL    3.5    6  Auto-S5   4WD  Gasoline    midsize car
# 3        ACURA TL    3.2    6  Auto-S5   2WD  Gasoline    midsize car
# 4        ACURA TL    3.5    6  Auto-S5   2WD  Gasoline    midsize car
# ...           ...    ...  ...      ...   ...       ...            ...
# 1004    VOLVO V70    3.2    6  Auto-S6   2WD  Gasoline  station wagon
# 1005  VOLVO XC 70    3.2    6  Auto-S6   4WD  Gasoline            SUV
# 1006  VOLVO XC 90    3.2    6  Auto-S6   2WD  Gasoline            SUV
# 1007  VOLVO XC 90    3.2    6  Auto-S6   4WD  Gasoline            SUV
# 1008  VOLVO XC 90    4.4    8  Auto-S6   4WD  Gasoline            SUV
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# ...

# %%
df_18 = df_18.reset_index().drop(['index'] , axis = 1)
df_18
# Out:
#            model  displ  cyl       trans drive                  fuel  \
# 0      ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1      ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 2      ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 3      ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 4      ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ..           ...    ...  ...         ...   ...                   ...
# 792  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 793  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 794  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 795  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 796  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#         veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0       small SUV                    3       20      28      23
# ...

# %%
# try using Pandas to_numeric or astype function to convert the
# 2008 air_pollution_score column to float -- this won't work
df_08.air_pollution_score = df_08.air_pollution_score.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2876/1121683101.py in <module>
#       1 # try using Pandas to_numeric or astype function to convert the
#       2 # 2008 air_pollution_score column to float -- this won't work
# ----> 3 df_08.air_pollution_score = df_08.air_pollution_score.astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
# ...

# %%
df_08['air_pollution_score'] = df_08['air_pollution_score'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2876/1896249512.py in <module>
# ----> 1 df_08['air_pollution_score'] = df_08['air_pollution_score'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
# ...

# %%
error_position = df_08.query('air_pollution_score == "6/4"')
print(error_position)
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                 6/4    13/18   19/25   15/21                  7/6       no

# %%
df_08.iloc[595]
# Out:
# model                   MERCEDES-BENZ C300
# displ                                  3.0
# cyl                                      6
# trans                              Auto-L7
# drive                                  2WD
# fuel                           ethanol/gas
# veh_class                        small car
# air_pollution_score                    6/4
# city_mpg                             13/18
# hwy_mpg                              19/25
# cmb_mpg                              15/21
# greenhouse_gas_score                   7/6
# smartway                                no
# Name: 595, dtype: object

# %% [markdown]
# If a vehicle can operate on more than one type of fuel, an estimate is provided for each fuel type."
#
# So all vehicles with more than one fuel type, or hybrids, like the one above (it uses ethanol AND gas) will have a string that holds two values - one for each.

# %%
# First, let's get all the hybrids in 2008
hb_08 = df_08[df_08['fuel'].str.contains('/')]
hb_08
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                 6/4    13/18   19/25   15/21                  7/6       no

# %%
hb_18 = df_18[df_18['fuel'].str.contains('/')]
hb_18.shape
# Out:
# (38, 13)

# %%
# create two copies of the 2008 hybrids dataframe
df1 = hb_08.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_08.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
df1
# Out:
#                   model  displ  cyl    trans drive         fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                 6/4    13/18   19/25   15/21                  7/6       no

# %%
# columns to split by "/"
split_columns = ['fuel', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
df1
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                   6       13      19      15                    7       no

# %%
df2
# Out:
#                   model  displ  cyl    trans drive fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                   4       18      25      21                    6       no

# %%
# combine dataframes to add to the original dataframe
new_rows = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_rows
# Out:
#                   model  displ  cyl    trans drive     fuel  veh_class  \
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
# 595  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD      gas  small car
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 595                   6       13      19      15                    7       no
# 595                   4       18      25      21                    6       no

# %%
# drop the original hybrid rows
df_08.drop(hb_08.index, inplace=True)

# add in our newly separated rows
df_08 = df_08.append(new_rows, ignore_index=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.shape
# Out:
# (1010, 13)

# %%
# same process for 2018 dataset

# create two copies of the 2008 hybrids dataframe
df1 = hb_18.copy()  # data on first fuel type of each hybrid vehicle
df2 = hb_18.copy()  # data on second fuel type of each hybrid vehicle

# Each one should look like this
df1
# Out:
#                                  model  displ  cyl       trans drive  \
# 53                            BMW 330e    2.0  4.0  SemiAuto-8   2WD
# 79                            BMW 530e    2.0  4.0  SemiAuto-8   2WD
# 80                            BMW 530e    2.0  4.0  SemiAuto-8   4WD
# 93                            BMW 740e    2.0  4.0  SemiAuto-8   4WD
# 190                   CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD
# 196             CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD
# 197             CHEVROLET Silverado 15    4.3  6.0      Auto-6   4WD
# 198             CHEVROLET Silverado 15    5.3  8.0      Auto-6   2WD
# 213            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   2WD
# 215            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   4WD
# 217               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   2WD
# 219               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   4WD
# 226                     CHEVROLET Volt    1.5  4.0         CVT   2WD
# ...

# %%
# columns to split by "/"
split_columns = ['fuel', 'city_mpg', 'hwy_mpg', 'cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c] = df1[c].apply(lambda x: x.split("/")[0])
    df2[c] = df2[c].apply(lambda x: x.split("/")[1])

# %%
df2
# Out:
#                                  model  displ  cyl       trans drive  \
# 53                            BMW 330e    2.0  4.0  SemiAuto-8   2WD
# 79                            BMW 530e    2.0  4.0  SemiAuto-8   2WD
# 80                            BMW 530e    2.0  4.0  SemiAuto-8   4WD
# 93                            BMW 740e    2.0  4.0  SemiAuto-8   4WD
# 190                   CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD
# 196             CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD
# 197             CHEVROLET Silverado 15    4.3  6.0      Auto-6   4WD
# 198             CHEVROLET Silverado 15    5.3  8.0      Auto-6   2WD
# 213            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   2WD
# 215            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   4WD
# 217               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   2WD
# 219               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   4WD
# 226                     CHEVROLET Volt    1.5  4.0         CVT   2WD
# ...

# %%
df1
# Out:
#                                  model  displ  cyl       trans drive  \
# 53                            BMW 330e    2.0  4.0  SemiAuto-8   2WD
# 79                            BMW 530e    2.0  4.0  SemiAuto-8   2WD
# 80                            BMW 530e    2.0  4.0  SemiAuto-8   4WD
# 93                            BMW 740e    2.0  4.0  SemiAuto-8   4WD
# 190                   CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD
# 196             CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD
# 197             CHEVROLET Silverado 15    4.3  6.0      Auto-6   4WD
# 198             CHEVROLET Silverado 15    5.3  8.0      Auto-6   2WD
# 213            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   2WD
# 215            CHEVROLET Suburban 1500    5.3  8.0      Auto-6   4WD
# 217               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   2WD
# 219               CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   4WD
# 226                     CHEVROLET Volt    1.5  4.0         CVT   2WD
# ...

# %%
# combine dataframes to add to the original dataframe
new_rows = df1.append(df2)

# now we have separate rows for each fuel type of each vehicle!
new_rows
# Out:
#                   model  displ  cyl       trans drive         fuel  \
# 53             BMW 330e    2.0  4.0  SemiAuto-8   2WD     Gasoline
# 79             BMW 530e    2.0  4.0  SemiAuto-8   2WD     Gasoline
# 80             BMW 530e    2.0  4.0  SemiAuto-8   4WD     Gasoline
# 93             BMW 740e    2.0  4.0  SemiAuto-8   4WD     Gasoline
# 190    CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD      Ethanol
# ..                  ...    ...  ...         ...   ...          ...
# 745  TOYOTA Sequoia FFV    5.7  8.0  SemiAuto-6   4WD          Gas
# 750   TOYOTA Tundra FFV    5.7  8.0  SemiAuto-6   4WD          Gas
# 780           VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Electricity
# 792         VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Electricity
# 796         VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Electricity
#
#         veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 53      small car                    3       28      34      30
# ...

# %%
# drop the original hybrid rows
df_18.drop(hb_18.index, inplace=True)

# add in our newly separated rows
df_18 = df_18.append(new_rows, ignore_index=True)

# %%
# check that all the original hybrid rows with "/"s are gone
df_18[df_18['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18.shape
# Out:
# (835, 13)

# %%
columns = ['city_mpg', 'hwy_mpg', 'cmb_mpg']

for c in columns:
    df_08[c] = df_08[c].astype(float)
    df_18[c] = df_18[c].astype(float)

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 835 non-null    object
#  1   displ                 835 non-null    float64
#  2   cyl                   835 non-null    float64
#  3   trans                 835 non-null    object
#  4   drive                 835 non-null    object
#  5   fuel                  835 non-null    object
#  6   veh_class             835 non-null    object
#  7   air_pollution_score   835 non-null    int64
#  8   city_mpg              835 non-null    float64
#  9   hwy_mpg               835 non-null    float64
#  10  cmb_mpg               835 non-null    float64
#  11  greenhouse_gas_score  835 non-null    int64
#  12  smartway              835 non-null    object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 84.9+ KB

# %%
df_08['greenhouse_gas_score'] = df_08['greenhouse_gas_score'].astype('int64')
df_18['greenhouse_gas_score'] = df_18['greenhouse_gas_score'].astype('int64')

# %%
df_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 835 non-null    object
#  1   displ                 835 non-null    float64
#  2   cyl                   835 non-null    float64
#  3   trans                 835 non-null    object
#  4   drive                 835 non-null    object
#  5   fuel                  835 non-null    object
#  6   veh_class             835 non-null    object
#  7   air_pollution_score   835 non-null    int64
#  8   city_mpg              835 non-null    float64
#  9   hwy_mpg               835 non-null    float64
#  10  cmb_mpg               835 non-null    float64
#  11  greenhouse_gas_score  835 non-null    int64
#  12  smartway              835 non-null    object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 84.9+ KB

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score      object
# city_mpg                float64
# hwy_mpg                 float64
# cmb_mpg                 float64
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_08.to_csv("D:/data analyst projects/fuel economy/clean_08.csv")
df_18.to_csv("D:/data analyst projects/fuel economy/clean_18.csv")

# %% [markdown]
# EXPLORING WITH VISUALS

# %%
df_08 = pd.read_csv("D:/data analyst projects/fuel economy/clean_08.csv")
df_18 = pd.read_csv("D:/data analyst projects/fuel economy/clean_18.csv")

# %%
df_08
# Out:
#       Unnamed: 0               model  displ  cyl    trans drive      fuel  \
# 0              0           ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline
# 1              1           ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline
# 2              2            ACURA RL    3.5    6  Auto-S5   4WD  Gasoline
# 3              3            ACURA TL    3.2    6  Auto-S5   2WD  Gasoline
# 4              4            ACURA TL    3.5    6  Auto-S5   2WD  Gasoline
# ...          ...                 ...    ...  ...      ...   ...       ...
# 1005        1005         VOLVO XC 90    3.2    6  Auto-S6   2WD  Gasoline
# 1006        1006         VOLVO XC 90    3.2    6  Auto-S6   4WD  Gasoline
# 1007        1007         VOLVO XC 90    4.4    8  Auto-S6   4WD  Gasoline
# 1008        1008  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD   ethanol
# 1009        1009  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD       gas
#
#         veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# ...

# %%
df_18
# Out:
#      Unnamed: 0               model  displ  cyl       trans drive  \
# 0             0           ACURA RDX    3.5  6.0  SemiAuto-6   2WD
# 1             1           ACURA RDX    3.5  6.0  SemiAuto-6   4WD
# 2             2           ACURA TLX    2.4  4.0       AMS-8   2WD
# 3             3           ACURA TLX    3.5  6.0  SemiAuto-9   2WD
# 4             4           ACURA TLX    3.5  6.0  SemiAuto-9   4WD
# ..          ...                 ...    ...  ...         ...   ...
# 830         830  TOYOTA Sequoia FFV    5.7  8.0  SemiAuto-6   4WD
# 831         831   TOYOTA Tundra FFV    5.7  8.0  SemiAuto-6   4WD
# 832         832           VOLVO S90    2.0  4.0  SemiAuto-8   4WD
# 833         833         VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD
# 834         834         VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD
#
#             fuel     veh_class  air_pollution_score  city_mpg  hwy_mpg  \
# 0       Gasoline     small SUV                    3      20.0     28.0
# ...

# %%
df_08.hist(figsize = (10,15));

# %%
df_18.hist(figsize = (10,15));

# %%
df_08.plot(x = 'displ' , y = 'cmb_mpg',kind = 'scatter');

# %%
df_08.plot(x = 'greenhouse_gas_score' , y = 'cmb_mpg',kind = 'scatter');

# %%
df_18.plot(x = 'displ' , y = 'cmb_mpg',kind = 'scatter');

# %%
df_18.plot(x = 'greenhouse_gas_score' , y = 'cmb_mpg',kind = 'scatter');

# %% [markdown]
# Looks like the alternative sources of fuel available in 2008 are CNG and ethanol, and those in 2018 ethanol and electricity.

# %%
# creating a query which has alternate fuels

af_08 = df_08.query('fuel in ["CNG" , "ethanol"]').model.nunique()
af_08
# Out:
# 2

# %%
af_18 = df_18.query('fuel in ["Ethanol" , "Electricity"]').model.nunique()
af_18
# Out:
# 26

# %% [markdown]
# **Are more unique models using alternative fuels in 2018 compared to 2008? By how much?**

# %%
# plotting the bar with x and resp y values
plt.bar(['2008' , '2018'] , [af_08 , af_18])
plt.title('Models using alternative fuels')
plt.xlabel('Year')
plt.ylabel('No. of unique models')
plt.show()

# %% [markdown]
# **How much have vehicle classes improved in fuel economy (increased in mpg)?**

# %%
# grouping data based on vehicle class and taking the mean of cmb_mpg for each group

vc_08 = df_08.groupby('veh_class')['cmb_mpg'].mean()
vc_08
# Out:
# veh_class
# SUV              18.472028
# large car        18.509091
# midsize car      21.571429
# minivan          19.117647
# pickup           16.388889
# small car        21.062130
# station wagon    22.366667
# van              14.833333
# Name: cmb_mpg, dtype: float64

# %%
vc_18 = df_18.groupby('veh_class')['cmb_mpg'].mean()
vc_18
# Out:
# veh_class
# large car          23.409091
# midsize car        27.827338
# minivan            20.800000
# pickup             18.589744
# small SUV          24.074074
# small car          25.421053
# special purpose    18.500000
# standard SUV       18.160920
# station wagon      27.628571
# Name: cmb_mpg, dtype: float64

# %%
# how much they have increased
inc = vc_18 - vc_08
inc
# Out:
# veh_class
# SUV                     NaN
# large car          4.900000
# midsize car        6.255910
# minivan            1.682353
# pickup             2.200855
# small SUV               NaN
# small car          4.358922
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.261905
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
# dropping those classes which are not common in both the data
inc.dropna(inplace = True)

# %%
# plotting the graph
plt.subplots(figsize=(8, 5))
plt.bar(inc.index, inc)
plt.title('Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Increase in Average Combined MPG');

# %%
inc.index
# Out:
# Index(['large car', 'midsize car', 'minivan', 'pickup', 'small car',
#        'station wagon'],
#       dtype='object', name='veh_class')

# %% [markdown]
# **What are the characteristics of SmartWay vehicles? Have they changed over time? (mpg, greenhouse gas)**

# %%
df_08.smartway.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df_18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
sm_08 = df_08.query('smartway == "yes"')
sm_08
# Out:
#       Unnamed: 0      model  displ  cyl    trans drive      fuel  \
# 3              3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline
# 4              4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline
# 5              5   ACURA TL    3.5    6    Man-6   2WD  Gasoline
# 7              7  ACURA TSX    2.4    4  Auto-S5   2WD  Gasoline
# 14            14    AUDI A3    2.0    4    Man-6   2WD  Gasoline
# ...          ...        ...    ...  ...      ...   ...       ...
# 998          998  VOLVO V50    2.4    5    Man-5   2WD  Gasoline
# 999          999  VOLVO V50    2.5    5    Man-6   4WD  Gasoline
# 1000        1000  VOLVO V50    2.5    5  Auto-S5   4WD  Gasoline
# 1001        1001  VOLVO V50    2.5    5  Auto-S5   2WD  Gasoline
# 1002        1002  VOLVO V50    2.5    5    Man-6   2WD  Gasoline
#
#           veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# 3       midsize car                  7.0      18.0     26.0     21.0
# ...

# %%
sm_08.describe()
# Out:
#         Unnamed: 0       displ         cyl  air_pollution_score    city_mpg  \
# count   382.000000  382.000000  382.000000           382.000000  382.000000
# mean    551.515707    2.601309    4.821990             7.363874   20.989529
# std     303.331672    0.622225    1.001174             1.145482    3.434409
# min       3.000000    1.300000    4.000000             6.000000   17.000000
# 25%     277.250000    2.225000    4.000000             7.000000   19.000000
# 50%     565.500000    2.400000    4.000000             7.000000   20.000000
# 75%     818.500000    3.000000    6.000000             7.000000   22.000000
# max    1002.000000    5.000000    8.000000             9.500000   48.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  382.000000  382.000000            382.000000
# mean    28.416230   23.740838              6.869110
# std      3.068261    3.053049              0.825218
# min     22.000000   20.000000              6.000000
# ...

# %%
mpg_08 = sm_08.cmb_mpg.mean()

# %%
ghs_08 = sm_08.greenhouse_gas_score.mean()
ghs_08
# Out:
# 6.869109947643979

# %%
df_18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
sm_18 = df_18.query('smartway in ["Yes" , "Elite"]')
sm_18
# Out:
#      Unnamed: 0                              model  displ  cyl       trans  \
# 16           16                      AUDI A4 Ultra    2.0  4.0       AMS-7
# 121         121                       BUICK Encore    1.4  4.0  SemiAuto-6
# 169         169                    CHEVROLET Cruze    1.4  4.0       Man-6
# 170         170                    CHEVROLET Cruze    1.4  4.0  SemiAuto-6
# 171         171                    CHEVROLET Cruze    1.6  4.0      Auto-9
# ..          ...                                ...    ...  ...         ...
# 815         815  FORD Fusion Energi Plug-in Hybrid    2.0  4.0         CVT
# 829         829     MINI Cooper SE Countryman All4    1.5  3.0  SemiAuto-6
# 832         832                          VOLVO S90    2.0  4.0  SemiAuto-8
# 833         833                        VOLVO XC 60    2.0  4.0  SemiAuto-8
# 834         834                        VOLVO XC 90    2.0  4.0  SemiAuto-8
#
# ...

# %%
sm_18.describe()
# Out:
#        Unnamed: 0       displ         cyl  air_pollution_score    city_mpg  \
# count  109.000000  109.000000  109.000000           109.000000  109.000000
# mean   524.963303    1.785321    3.935780             5.192661   34.853211
# std    224.592344    0.407073    0.414444             1.802658   16.365516
# min     16.000000    1.200000    3.000000             3.000000   25.000000
# 25%    339.000000    1.500000    4.000000             3.000000   28.000000
# 50%    574.000000    1.600000    4.000000             5.000000   29.000000
# 75%    704.000000    2.000000    4.000000             7.000000   31.000000
# max    834.000000    3.500000    6.000000             7.000000  113.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  109.000000  109.000000            109.000000
# mean    41.422018   37.302752              7.917431
# std     13.045003   14.792080              1.195117
# min     27.000000   26.000000              7.000000
# ...

# %%
mpg_18 = sm_18.cmb_mpg.mean()

# %%
ghs_18 = sm_18.greenhouse_gas_score.mean()

# %%
plt.bar(['2008' , '2018'],[mpg_08 , mpg_18])
plt.title('Changes in mpg')
plt.ylabel('mean mpg')
plt.xlabel('year')
plt.show()

# %%
plt.bar(['2008' , '2018'],[ghs_08 , ghs_18])
plt.title('Changes in Greenhouse Gas score')
plt.ylabel('Mean Greenhouse Gas Score')
plt.xlabel('year')
plt.show()

# %% [markdown]
# **What features are associated with better fuel economy (mpg)?**

# %%
df_08.cmb_mpg.describe()
# Out:
# count    1010.000000
# mean       19.740594
# std         4.241710
# min        10.000000
# 25%        17.000000
# 50%        20.000000
# 75%        22.000000
# max        46.000000
# Name: cmb_mpg, dtype: float64

# %%
# selecting all vehicles that have the top 50% fuel economy ratings like this.

top_08 = df_08.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#         Unnamed: 0       displ         cyl  air_pollution_score    city_mpg  \
# count   525.000000  525.000000  525.000000           525.000000  525.000000
# mean    544.577143    2.670857    4.887619             6.990476   20.308571
# std     308.824860    0.665829    1.034122             1.156175    3.188724
# min       3.000000    1.300000    4.000000             4.000000   17.000000
# 25%     241.000000    2.300000    4.000000             6.000000   18.000000
# 50%     569.000000    2.500000    4.000000             7.000000   20.000000
# 75%     832.000000    3.000000    6.000000             7.000000   21.000000
# max    1009.000000    6.000000    8.000000             9.500000   48.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  525.000000  525.000000            525.000000
# mean    27.588571   22.980952              6.636190
# std      3.043931    2.918685              0.802563
# min     20.000000   20.000000              6.000000
# ...

# %%
top_08 = top_08.drop('Unnamed: 0' , axis = 'columns')

# %%
top_18 = df_18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe()
# Out:
#        Unnamed: 0       displ         cyl  air_pollution_score    city_mpg  \
# count  329.000000  329.000000  329.000000           329.000000  329.000000
# mean   442.960486    1.962918    4.021277             4.851064   27.477204
# std    249.238612    0.398808    0.464768             1.860781   11.017182
# min      2.000000    1.200000    3.000000             1.000000   21.000000
# 25%    202.000000    1.600000    4.000000             3.000000   23.000000
# 50%    462.000000    2.000000    4.000000             5.000000   25.000000
# 75%    675.000000    2.000000    4.000000             7.000000   28.000000
# max    834.000000    3.500000    6.000000             7.000000  113.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  329.000000  329.000000            329.000000
# mean    35.306991   30.413374              6.331307
# std      9.011171   10.066211              1.408692
# min     27.000000   25.000000              4.000000
# ...

# %%
top_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  525.000000  525.000000           525.000000  525.000000  525.000000
# mean     2.670857    4.887619             6.990476   20.308571   27.588571
# std      0.665829    1.034122             1.156175    3.188724    3.043931
# min      1.300000    4.000000             4.000000   17.000000   20.000000
# 25%      2.300000    4.000000             6.000000   18.000000   25.000000
# 50%      2.500000    4.000000             7.000000   20.000000   27.000000
# 75%      3.000000    6.000000             7.000000   21.000000   29.000000
# max      6.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  525.000000            525.000000
# mean    22.980952              6.636190
# std      2.918685              0.802563
# min     20.000000              6.000000
# 25%     21.000000              6.000000
# 50%     22.000000              6.000000
# ...

# %%
top_18 = top_18.drop('Unnamed: 0' , axis = 'columns')

# %%
top_18 = top_18.mean()
top_18
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_2876/1249174412.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   top_18 = top_18.mean()
# displ                    1.962918
# cyl                      4.021277
# air_pollution_score      4.851064
# city_mpg                27.477204
# hwy_mpg                 35.306991
# cmb_mpg                 30.413374
# greenhouse_gas_score     6.331307
# dtype: float64

# %%
top_08 = top_08.mean()
top_08
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_2876/1710713177.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   top_08 = top_08.mean()
# displ                    2.670857
# cyl                      4.887619
# air_pollution_score      6.990476
# city_mpg                20.308571
# hwy_mpg                 27.588571
# cmb_mpg                 22.980952
# greenhouse_gas_score     6.636190
# dtype: float64

# %%
# plotting both the graphs together
ind = np.arange(len(top_08))
width = 0.35

plt.subplots(figsize = (10,10))
bars_08 = plt.bar(ind , top_08 , width , color = 'r' , label = '2008 DATA')
bars_18 = plt.bar(ind+width , top_18 , width , color = 'k' , label = '2018 DATA')

plt.title('Factors affecting fuel efficiency')

plt.ylabel('mean values')
plt.xlabel('Features affecting fuel efficiency')

location = ind + width/2
labels = ['displ','cyl','air_pollution_score','city_mpg','hwy_mpg','cmb_mpg','greenhouse_gas_score']

plt.xticks(location , labels)
plt.legend()
plt.show()

# %% [markdown]
# ** **

# %% [markdown]
# **For all of the models that were produced in 2008 that are still being produced in 2018, how much has the mpg improved and which vehicle improved the most?**

# %%
# first renaming the column of 2008 datatset so that the there wont be any confusion about which data is of which year.

df_08.rename(columns = lambda x: x[:10] + '_2008' , inplace = True)
df_08
# Out:
#       Unnamed: 0_2008          model_2008  displ_2008  cyl_2008 trans_2008  \
# 0                   0           ACURA MDX         3.7         6    Auto-S5
# 1                   1           ACURA RDX         2.3         4    Auto-S5
# 2                   2            ACURA RL         3.5         6    Auto-S5
# 3                   3            ACURA TL         3.2         6    Auto-S5
# 4                   4            ACURA TL         3.5         6    Auto-S5
# ...               ...                 ...         ...       ...        ...
# 1005             1005         VOLVO XC 90         3.2         6    Auto-S6
# 1006             1006         VOLVO XC 90         3.2         6    Auto-S6
# 1007             1007         VOLVO XC 90         4.4         8    Auto-S6
# 1008             1008  MERCEDES-BENZ C300         3.0         6    Auto-L7
# 1009             1009  MERCEDES-BENZ C300         3.0         6    Auto-L7
#
# ...

# %%
df_08.drop('Unnamed: 0_2008' , axis = 'columns' , inplace = True)

# %%
df_18.drop('Unnamed: 0' , axis = 'columns' , inplace = True)

# %%
combined_df = pd.merge(df_08 , df_18 , how = 'inner' , left_on = 'model_2008' , right_on = 'model')
combined_df.head()
# Out:
#   model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1  ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3    AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4    AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
#
#   veh_class_2008  air_pollut_2008  city_mpg_2008  hwy_mpg_2008  ...  \
# 0            SUV              7.0           17.0          22.0  ...
# 1            SUV              7.0           17.0          22.0  ...
# 2  station wagon              7.0           21.0          29.0  ...
# 3  station wagon              7.0           21.0          29.0  ...
# 4  station wagon              7.0           22.0          29.0  ...
#
#         trans  drive      fuel  veh_class  air_pollution_score  city_mpg  \
# 0  SemiAuto-6    2WD  Gasoline  small SUV                    3      20.0
# ...

# %%
combined_df.shape
# Out:
# (930, 26)

# %%
# save file to local
# combined_df.to_csv("D:/data analyst projects/fuel economy/combined_df.csv")

# %%
model_mpg = pd.read_csv("D:/data analyst projects/fuel economy/combined_df.csv")
model_mpg
# Out:
#      Unnamed: 0          model_2008  displ_2008  cyl_2008 trans_2008  \
# 0             0           ACURA RDX         2.3         4    Auto-S5
# 1             1           ACURA RDX         2.3         4    Auto-S5
# 2             2             AUDI A3         2.0         4      Man-6
# 3             3             AUDI A3         2.0         4      Man-6
# 4             4             AUDI A3         2.0         4    Auto-S6
# ..          ...                 ...         ...       ...        ...
# 925         925  MERCEDES-BENZ C300         3.0         6    Auto-L7
# 926         926  MERCEDES-BENZ C300         3.0         6    Auto-L7
# 927         927  MERCEDES-BENZ C300         3.0         6    Auto-L7
# 928         928  MERCEDES-BENZ C300         3.0         6    Auto-L7
# 929         929  MERCEDES-BENZ C300         3.0         6    Auto-L7
#
#     drive_2008 fuel_2008 veh_class_2008  air_pollut_2008  city_mpg_2008  ...  \
# ...

# %%
model_mpg = model_mpg.groupby(['model'])
model_mpg = model_mpg['cmb_mpg_2008' , 'cmb_mpg'].mean()
model_mpg
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_2876/1910081777.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   model_mpg = model_mpg['cmb_mpg_2008' , 'cmb_mpg'].mean()
#                    cmb_mpg_2008    cmb_mpg
# model
# ACURA RDX             19.000000  22.500000
# AUDI A3               23.333333  28.000000
# AUDI A4               21.000000  27.000000
# AUDI A6               19.666667  25.666667
# AUDI A8 L             16.500000  22.000000
# ...                         ...        ...
# TOYOTA Yaris          31.500000  32.500000
# VOLKSWAGEN Jetta      24.166667  30.000000
# VOLKSWAGEN Passat     21.250000  29.000000
# VOLVO S60             21.333333  27.000000
# VOLVO XC 90           15.666667  32.200000
#
# [72 rows x 2 columns]

# %%
model_mpg.shape
# Out:
# (72, 2)

# %%
model_mpg['mpg_change'] = model_mpg['cmb_mpg']- model_mpg['cmb_mpg_2008']
model_mpg
# Out:
#                    cmb_mpg_2008    cmb_mpg  mpg_change
# model
# ACURA RDX             19.000000  22.500000    3.500000
# AUDI A3               23.333333  28.000000    4.666667
# AUDI A4               21.000000  27.000000    6.000000
# AUDI A6               19.666667  25.666667    6.000000
# AUDI A8 L             16.500000  22.000000    5.500000
# ...                         ...        ...         ...
# TOYOTA Yaris          31.500000  32.500000    1.000000
# VOLKSWAGEN Jetta      24.166667  30.000000    5.833333
# VOLKSWAGEN Passat     21.250000  29.000000    7.750000
# VOLVO S60             21.333333  27.000000    5.666667
# VOLVO XC 90           15.666667  32.200000   16.533333
#
# [72 rows x 3 columns]

# %%
model_mpg.sort_values(by = 'mpg_change' , ascending = False)
# Out:
#                       cmb_mpg_2008    cmb_mpg  mpg_change
# model
# VOLVO XC 90              15.666667  32.200000   16.533333
# CHEVROLET Malibu         22.333333  33.000000   10.666667
# CHEVROLET Equinox        19.000000  27.833333    8.833333
# AUDI S4                  15.500000  24.000000    8.500000
# AUDI S5                  16.000000  24.000000    8.000000
# ...                            ...        ...         ...
# TOYOTA Tundra            15.400000  15.250000   -0.150000
# CHEVROLET Corvette       18.000000  17.750000   -0.250000
# TOYOTA Sequoia           14.750000  14.500000   -0.250000
# BMW 750i                 20.000000  19.500000   -0.500000
# MASERATI Granturismo     17.000000  16.000000   -1.000000
#
# [72 rows x 3 columns]
